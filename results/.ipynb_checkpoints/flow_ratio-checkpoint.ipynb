# %%
# https://zhuanlan.zhihu.com/p/437747308

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

base_dir = '../record/local/monax_cubic_5_same_96m/'
file_list = os.listdir(base_dir)

file_list.sort()

flow = {}


data = {}

data["Time (s)"] = []
data["Throughput (Mbps)"] = []
data["Flow"] = []

throughput = {}

compare_cc = "cubic"

for file in file_list:
    if('csv' in file):
        flow_id = int(file.split('_')[1])
        CC = file.split('_')[2]
        df = pd.read_csv(os.path.join(base_dir,file))
        time = df['time'].values
        delivery_rate = df['delivery_rate']
        
        if(CC not in throughput):
            throughput[CC] = []
        throughput[CC].append(np.average(delivery_rate))
        
        if(flow_id == 0):
            min_time = min(time)
            time = time - min_time
        else:
            time = time - min_time
        time = np.append(time, time[-1]+1)
        delivery_rate = np.append(delivery_rate, 0)
                        
        data["Time (s)"]+=(list(time))
        data["Throughput (Mbps)"]+=(list(delivery_rate))
        data["Flow"]+=(list(["Flow "+str(flow_id+1)]*len(delivery_rate)))
        
        
        print(f"flow #{flow_id}: length = {len(delivery_rate)}")
        
        flow[flow_id] = delivery_rate
        

throughput_avg = {}      
for cc in throughput:
    throughput_avg[cc] = np.average(throughput[cc])
    

throughput_ratio = throughput_avg["monax"] / throughput_avg[compare_cc]
    
print(throughput)
print(throughput_avg)
print(f"Throughput ratio = {throughput_ratio}")
# Out:
# flow #0: length = 3063
# flow #1: length = 5427
# flow #2: length = 5535
# flow #3: length = 5532
# flow #4: length = 5526
# flow #5: length = 5407
# {'monax': [14.7530437622469], 'cubic': [15.474655363066718, 15.515048789302494, 15.617881034171036, 15.526745701357465, 15.487491675915651]}
# {'monax': 14.7530437622469, 'cubic': 15.524364512762673}
# Throughput ratio = 0.9503154702479663

# %%
X_LIMIT = (0, 240)
Y_LIMIT = (0, 20)

sns.set(font_scale=2)
sns.set_style("whitegrid")


g = sns.relplot(x="Time (s)", y="Throughput (Mbps)", hue="Flow", height=8, aspect=15/8,
                palette=['orange', 'orchid', 'purple', 'blue'], linewidth = 3,
                estimator=None,
                kind="line", data=data)

g._legend.set_title("  ")

for lh in g._legend.legendHandles: 
    lh.set_alpha(1)
    lh._sizes = [500] 
    lh._linewidth = 5
    
g.set(xlim=X_LIMIT,ylim=Y_LIMIT)
g.set_ylabels(fontsize=30)
g.set_xlabels(fontsize=30)

g.savefig("./fairness.png", dpi = 400)
